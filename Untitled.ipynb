# %%
from statsmodels.stats.weightstats import _zconfint_generic
# получаем выборку ушедших
dfchurn=df[df['churn']]
# получаем столбец total day calls
calls_churn=dfchurn['total day calls']
# получаем выборку не ушедших
dfnot_churn=df[ df['churn']==False]
# получаем столбец total day calls
calls_not_churn=dfnot_churn['total day calls']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13864\1550357399.py in <module>
#       1 from statsmodels.stats.weightstats import _zconfint_generic
#       2 # получаем выборку ушедших
# ----> 3 dfchurn=df[df['churn']]
#       4 # получаем столбец total day calls
#       5 calls_churn=dfchurn['total day calls']
#
# NameError: name 'df' is not defined

# %%
# либо загружаем из альтернативного хранилища
url ="https://raw.githubusercontent.com/piton1/DS/Lesson_5/telecom_churn.csv"
df=pd.read_csv(url)
display(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13864\350630286.py in <module>
#       1 # либо загружаем из альтернативного хранилища
#       2 url ="https://raw.githubusercontent.com/piton1/DS/Lesson_5/telecom_churn.csv"
# ----> 3 df=pd.read_csv(url)
#       4 display(df)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import math
# %matplotlib inline

# %%
# либо загружаем из альтернативного хранилища
url ="https://raw.githubusercontent.com/piton1/DS/Lesson_5/telecom_churn.csv"
df=pd.read_csv(url)
display(df)
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
from statsmodels.stats.weightstats import _zconfint_generic
# получаем выборку ушедших
dfchurn=df[df['churn']]
# получаем столбец total day calls
calls_churn=dfchurn['total day calls']
# получаем выборку не ушедших
dfnot_churn=df[ df['churn']==False]
# получаем столбец total day calls
calls_not_churn=dfnot_churn['total day calls']

# %%
N1=len(dfchurn)
print('число ушедших ',N1)
m1=calls_churn.mean()
print('среднее число дневных звонков для ушедших ',m1)
std1=calls_churn.std(ddof=1)
print('стандартное отклонение  числа дневных звонков для ушедших ',std1)
# доверительная вероятность
prob=0.95
# квантиль N(0;1)
u=sts.norm.ppf((1+prob)/2, loc=0, scale=1)
print(prob*100,'%-й доверительный интервал для среднего значения числа дневных звонков для ушедших по формуле') 
print('(',m1-u*std1/math.sqrt(N1),';',m1+u*std1/math.sqrt(N1),')')
print(prob*100,'%-й доверительный интервал для среднего значения числа дневных звонков для ушедших с помощью функции') 
print(zconfint(calls_churn, alpha=0.05, alternative="two-sided"))
# Out:
# число ушедших  483
# среднее число дневных звонков для ушедших  101.33540372670808
# стандартное отклонение  числа дневных звонков для ушедших  21.58230721307551
# 95.0 %-й доверительный интервал для среднего значения числа дневных звонков для ушедших по формуле
# ( 99.41066229112079 ; 103.26014516229537 )
# 95.0 %-й доверительный интервал для среднего значения числа дневных звонков для ушедших с помощью функции
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13864\2341594413.py in <module>
#      12 print('(',m1-u*std1/math.sqrt(N1),';',m1+u*std1/math.sqrt(N1),')')
#      13 print(prob*100,'%-й доверительный интервал для среднего значения числа дневных звонков для ушедших с помощью функции')
# ---> 14 print(zconfint(calls_churn, alpha=0.05, alternative="two-sided"))
#
# NameError: name 'zconfint' is not defined

# %%
from statsmodels.stats.weightstats import _zconfint_generic
# получаем выборку ушедших
dfchurn=df[df['churn']]
# получаем столбец total day calls
calls_churn=dfchurn['total day calls']
# получаем выборку не ушедших
dfnot_churn=df[ df['churn']==False]
# получаем столбец total day calls
calls_not_churn=dfnot_churn['total day calls']
N1=len(dfchurn)
print('число ушедших ',N1)
m1=calls_churn.mean()
print('среднее число дневных звонков для ушедших ',m1)
std1=calls_churn.std(ddof=1)
print('стандартное отклонение  числа дневных звонков для ушедших ',std1)
# доверительная вероятность
prob=0.95
# квантиль N(0;1)
u=sts.norm.ppf((1+prob)/2, loc=0, scale=1)
print(prob*100,'%-й доверительный интервал для среднего значения числа дневных звонков для ушедших по формуле') 
print('(',m1-u*std1/math.sqrt(N1),';',m1+u*std1/math.sqrt(N1),')')
print(prob*100,'%-й доверительный интервал для среднего значения числа дневных звонков для ушедших с помощью функции') 
print(zconfint(calls_churn, alpha=0.05, alternative="two-sided"))
# Out:
# число ушедших  483
# среднее число дневных звонков для ушедших  101.33540372670808
# стандартное отклонение  числа дневных звонков для ушедших  21.58230721307551
# 95.0 %-й доверительный интервал для среднего значения числа дневных звонков для ушедших по формуле
# ( 99.41066229112079 ; 103.26014516229537 )
# 95.0 %-й доверительный интервал для среднего значения числа дневных звонков для ушедших с помощью функции
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13864\1734039818.py in <module>
#      21 print('(',m1-u*std1/math.sqrt(N1),';',m1+u*std1/math.sqrt(N1),')')
#      22 print(prob*100,'%-й доверительный интервал для среднего значения числа дневных звонков для ушедших с помощью функции')
# ---> 23 print(zconfint(calls_churn, alpha=0.05, alternative="two-sided"))
#
# NameError: name 'zconfint' is not defined

# %%
from statsmodels.stats.weightstats import _zconfint_generic
# получаем выборку ушедших
dfchurn=df[df['churn']]
# получаем столбец total day calls
calls_churn=dfchurn['total day calls']
# получаем выборку не ушедших
dfnot_churn=df[ df['churn']==False]
# получаем столбец total day calls
calls_not_churn=dfnot_churn['total day calls']

N1=len(dfchurn)
print('число ушедших ',N1)
m1=calls_churn.mean()
print('среднее число дневных звонков для ушедших ',m1)
std1=calls_churn.std(ddof=1)
print('стандартное отклонение  числа дневных звонков для ушедших ',std1)
# доверительная вероятность
prob=0.95
# квантиль N(0;1)
u=sts.norm.ppf((1+prob)/2, loc=0, scale=1)
print(prob*100,'%-й доверительный интервал для среднего значения числа дневных звонков для ушедших по формуле') 
print('(',m1-u*std1/math.sqrt(N1),';',m1+u*std1/math.sqrt(N1),')')
print(prob*100,'%-й доверительный интервал для среднего значения числа дневных звонков для ушедших с помощью функции') 
print(zconfint(calls_churn, alpha=0.05, alternative="two-sided"))

print()
N2=len(dfnot_churn)
print('число не ушедших ',N2)
m2=calls_not_churn.mean()
print('среднее число дневных звонков для не ушедших ',m2)
std2=calls_not_churn.std(ddof=1)
print('стандартное отклонение  числа дневных звонков для не ушедших ',std2)
print(prob*100,'%-й доверительный интервал для среднего значения числа дневных звонков для не ушедших по формуле') 
print('(',m2-u*std2/math.sqrt(N2),';',m2+u*std2/math.sqrt(N2),')')
print(prob*100,'%-й доверительный интервал для среднего значения числа дневных звонков для не ушедших с помощью функции') 
print(zconfint(calls_not_churn, alpha=0.05, alternative="two-sided"))
# Out:
# число ушедших  483
# среднее число дневных звонков для ушедших  101.33540372670808
# стандартное отклонение  числа дневных звонков для ушедших  21.58230721307551
# 95.0 %-й доверительный интервал для среднего значения числа дневных звонков для ушедших по формуле
# ( 99.41066229112079 ; 103.26014516229537 )
# 95.0 %-й доверительный интервал для среднего значения числа дневных звонков для ушедших с помощью функции
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13864\2920696325.py in <module>
#      22 print('(',m1-u*std1/math.sqrt(N1),';',m1+u*std1/math.sqrt(N1),')')
#      23 print(prob*100,'%-й доверительный интервал для среднего значения числа дневных звонков для ушедших с помощью функции')
# ---> 24 print(zconfint(calls_churn, alpha=0.05, alternative="two-sided"))
#      25
#      26 print()
#
# NameError: name 'zconfint' is not defined
